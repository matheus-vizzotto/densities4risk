# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
from scipy.stats import t
from scipy.stats import norm


from scipy.stats import gaussian_kde
from statsmodels.nonparametric.kde import KDEUnivariate
from sklearn.neighbors import KernelDensity

from sklearn.model_selection import GridSearchCV, LeaveOneOut
from sklearn.model_selection import ParameterGrid

import sys
sys.path.append("..")
from src.preprocessing import KernelDensityEstimation, fit_kde_model, df_to_densities
from src.plotting import plot_2d_fts, plot_3d_fts

# %%
data_path = "../data/processed/"
returns_path = ''.join([data_path, 'ibovespa_treated.xlsx'])
df = pd.read_excel(returns_path, index_col="time")
df.head()
# Out:
#           2024-12-02  2024-12-03  2024-12-04  2024-12-05  2024-12-06  \
# time
# 10:00:00    0.000011   -0.000372   -0.000035    0.007233   -0.001305
# 10:05:00   -0.002271    0.003372    0.001716    0.005538    0.000069
# 10:10:00   -0.000582    0.002832   -0.000502    0.000739    0.000261
# 10:15:00   -0.001997    0.001091    0.000111   -0.000192    0.000407
# 10:20:00   -0.000037   -0.000505   -0.000327   -0.000580   -0.000436
#
#           2024-12-09  2024-12-10  2024-12-11  2024-12-12  2024-12-13  ...  \
# time                                                                  ...
# 10:00:00   -0.000459    0.002388    0.002212   -0.008001   -0.000824  ...
# 10:05:00    0.006429    0.002343    0.001918   -0.007582   -0.000413  ...
# 10:10:00    0.001891    0.000775   -0.001172    0.000216   -0.000432  ...
# 10:15:00   -0.001392   -0.000477   -0.001526    0.000198   -0.001821  ...
# 10:20:00   -0.000405    0.001263    0.000676   -0.002667    0.001033  ...
#
# ...

# %%
density_model          f_star
kernel           epanechnikov
bandwidth                  cv
adaptive                 True
KLD                  0.137862
JSD                  0.003278
L_1                  0.022221
L_2                  0.006453
L_INFTY              0.003727
win_KLD                 False
win_JSD                  True
win_L_1                  True
win_L_2                  True
win_L_INFTY              True
n_wins                      4

# %%
params = {"kernel": "epanechnikov", "bandwidth": "cv", "adaptive": True}
grid, densities = df_to_densities(df, params)

# %%
plot_3d_fts(
    densities, 
    grid, 
    densities.columns, 
    title_ = "Estimated density over time",
    axis_titles=['x', 'Date', 'Density'],
    color_scale='PuOr',
    output_angle = [-0.7, -2.5, 0.8]
    )

# %%
plot_3d_fts(
    df_lqds, 
    lqdSup, 
    df_lqds.columns, 
    title_="LQDensities",
    color_scale='turbo',
    axis_titles=['u', 'Date', 'LQDensity'],
    output_angle = [-0.7, -2.5, 0.8],
    output_path=''.join([doc_path, 'lqdensities_3d.png'])
    )
