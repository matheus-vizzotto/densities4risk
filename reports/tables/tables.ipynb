# %%
import pandas as pd

tables_path = "../../data/processed/"

# %%
cv_results = pd.read_excel('/'.join([tables_path, 'cv_density_estimation_v3.xlsx']))#.drop(columns=["Unnamed: 0"])
cv_results = cv_results[["kernel", "bandwidth", "adaptive", "normalized_density", "KLD", "JSD", "L_1", "L_2", "L_INFTY"]]
cv_results_summary = cv_results.groupby(["kernel", "bandwidth", "adaptive", "normalized_density"], as_index=False).mean()

# %%
corresp_cols =  {
    "kernel": "Kernel",
    "bandwidth": "Bandwidth", 
    "adaptive":  "Adaptive bandwidth", 
    "normalized_density": "Normalized pdf", 
    "L_1": "$L_1$", 
    "L_2": "$L_2$", 
    "L_INFTY": "$L_{\infty}$$"
    }
cv_results_summary.rename(columns=corresp_cols, inplace=True)
cv_results_summary.sort_values(by="JSD", inplace=True)
cv_results_summary.head()
# Out:
#             Kernel  Bandwidth  Adaptive bandwidth  Normalized pdf       KLD  \
# 17  t_student_df_2      scott               False            True  0.031019
# 25  t_student_df_3      scott               False            True  0.033420
# 21  t_student_df_2  silverman               False            True  0.033027
# 19  t_student_df_2      scott                True            True  0.030355
# 33  t_student_df_4      scott               False            True  0.034623
#
#          JSD         $L_1$       $L_2$  $L_{\infty}$$
# 17  0.001947  13395.557790  820.615430      97.602137
# 25  0.002048  13572.495539  841.593260      99.624500
# 21  0.002083  13996.626133  891.917368     110.507435
# 19  0.002093  14457.123869  977.094354     128.389904
# 33  0.002096  13648.596031  851.954509     100.569938

# %%
formatted_cv_summary = (   
    cv_results_summary.style
    .background_gradient(
        cmap="RdYlGn_r",   # green = low, red = high
        axis=0            # column-wise
    )
    .format(precision=4)
)
formatted_cv_summary
# Out:
# <style type="text/css">
# #T_a5eec_row0_col4, #T_a5eec_row0_col5, #T_a5eec_row0_col6, #T_a5eec_row0_col7, #T_a5eec_row0_col8, #T_a5eec_row3_col4, #T_a5eec_row6_col4, #T_a5eec_row9_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a5eec_row1_col4, #T_a5eec_row1_col8, #T_a5eec_row2_col4, #T_a5eec_row4_col4, #T_a5eec_row11_col4, #T_a5eec_row13_col4, #T_a5eec_row14_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_a5eec_row1_col5, #T_a5eec_row1_col6, #T_a5eec_row4_col6, #T_a5eec_row4_col8, #T_a5eec_row5_col4, #T_a5eec_row7_col4, #T_a5eec_row8_col4, #T_a5eec_row10_col4, #T_a5eec_row12_col4, #T_a5eec_row15_col4, #T_a5eec_row16_col4, #T_a5eec_row17_col4 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_a5eec_row1_col7, #T_a5eec_row5_col5, #T_a5eec_row8_col6, #T_a5eec_row19_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_a5eec_row2_col5, #T_a5eec_row3_col5, #T_a5eec_row4_col5, #T_a5eec_row5_col6, #T_a5eec_row5_col8, #T_a5eec_row18_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_a5eec_row2_col6, #T_a5eec_row4_col7, #T_a5eec_row9_col5, #T_a5eec_row10_col5 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_a5eec_row2_col7, #T_a5eec_row9_col6, #T_a5eec_row10_col8, #T_a5eec_row22_col4 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_a5eec_row2_col8, #T_a5eec_row12_col6, #T_a5eec_row14_col5, #T_a5eec_row21_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_a5eec_row3_col6, #T_a5eec_row27_col8 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_a5eec_row3_col7, #T_a5eec_row18_col6 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_a5eec_row3_col8, #T_a5eec_row17_col6, #T_a5eec_row39_col8 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_a5eec_row5_col7, #T_a5eec_row11_col5, #T_a5eec_row12_col5 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_a5eec_row6_col5, #T_a5eec_row8_col8 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_a5eec_row6_col6, #T_a5eec_row15_col5, #T_a5eec_row16_col5 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_a5eec_row6_col7, #T_a5eec_row43_col8 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_a5eec_row6_col8, #T_a5eec_row24_col4, #T_a5eec_row32_col4 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_a5eec_row7_col5, #T_a5eec_row8_col5 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_a5eec_row7_col6, #T_a5eec_row13_col5 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_a5eec_row7_col7, #T_a5eec_row37_col8 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_a5eec_row7_col8, #T_a5eec_row8_col7, #T_a5eec_row17_col5 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_a5eec_row9_col7, #T_a5eec_row19_col5 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_a5eec_row9_col8, #T_a5eec_row42_col8 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_a5eec_row10_col6 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_a5eec_row10_col7, #T_a5eec_row13_col6, #T_a5eec_row27_col4, #T_a5eec_row30_col4, #T_a5eec_row31_col8 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_a5eec_row11_col6, #T_a5eec_row12_col8, #T_a5eec_row23_col4 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_a5eec_row11_col7, #T_a5eec_row20_col5 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_a5eec_row11_col8, #T_a5eec_row33_col4 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_a5eec_row12_col7, #T_a5eec_row14_col6, #T_a5eec_row41_col8 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_a5eec_row13_col7, #T_a5eec_row27_col7 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_a5eec_row13_col8, #T_a5eec_row28_col8, #T_a5eec_row38_col4 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_a5eec_row14_col7 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_a5eec_row14_col8, #T_a5eec_row25_col8, #T_a5eec_row35_col4 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_a5eec_row15_col6, #T_a5eec_row20_col4, #T_a5eec_row31_col4 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_a5eec_row15_col7 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_a5eec_row15_col8 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_a5eec_row16_col6, #T_a5eec_row19_col6 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_a5eec_row16_col7, #T_a5eec_row32_col8, #T_a5eec_row40_col4 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_a5eec_row16_col8 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_a5eec_row17_col7, #T_a5eec_row38_col8 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_a5eec_row17_col8 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_a5eec_row18_col5 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_a5eec_row18_col7, #T_a5eec_row37_col7 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_a5eec_row18_col8, #T_a5eec_row33_col8 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_a5eec_row19_col7, #T_a5eec_row20_col8, #T_a5eec_row33_col5, #T_a5eec_row41_col7 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_a5eec_row19_col8, #T_a5eec_row45_col7, #T_a5eec_row47_col4, #T_a5eec_row47_col5, #T_a5eec_row47_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a5eec_row20_col6 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_a5eec_row20_col7, #T_a5eec_row35_col6 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_a5eec_row21_col5 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_a5eec_row21_col6, #T_a5eec_row30_col5 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_a5eec_row21_col7 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_a5eec_row21_col8, #T_a5eec_row33_col6 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_a5eec_row22_col5 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_a5eec_row22_col6 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_a5eec_row22_col7 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_a5eec_row22_col8 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_a5eec_row23_col5, #T_a5eec_row24_col5, #T_a5eec_row31_col7 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_a5eec_row23_col6, #T_a5eec_row27_col6 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_a5eec_row23_col7 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_a5eec_row23_col8 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_a5eec_row24_col6 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_a5eec_row24_col7 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_a5eec_row24_col8, #T_a5eec_row32_col6 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_a5eec_row25_col4, #T_a5eec_row36_col8 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_a5eec_row25_col5, #T_a5eec_row39_col7 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_a5eec_row25_col6 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_a5eec_row25_col7, #T_a5eec_row34_col5, #T_a5eec_row40_col7 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_a5eec_row26_col4, #T_a5eec_row35_col8 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_a5eec_row26_col5 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_a5eec_row26_col6, #T_a5eec_row36_col5 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_a5eec_row26_col7 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_a5eec_row26_col8 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_a5eec_row27_col5, #T_a5eec_row35_col7 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_a5eec_row28_col4 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_a5eec_row28_col5 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_a5eec_row28_col6 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_a5eec_row28_col7, #T_a5eec_row42_col7 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_a5eec_row29_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_a5eec_row29_col5 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_a5eec_row29_col6 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_a5eec_row29_col7, #T_a5eec_row30_col8 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_a5eec_row29_col8, #T_a5eec_row39_col4 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_a5eec_row30_col6, #T_a5ee

# %%
formatted_cv_summary.to_latex(
    buf     = "cv_results_code.tex",
    caption = "Results for expanding window cross-validation t+1 forecasts.",
    label   = "tab:cv_results",
    # index   = False,
    hrules  = True
    )
